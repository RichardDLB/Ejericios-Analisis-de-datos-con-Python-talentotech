# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardDLB/Ejericios-Analisis-de-datos-con-Python-talentotech/blob/main/EjercicioPractico2Clase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejercicio práctico
# 1. Cargar un csv en Google Colab y visualizar sus primeras filas usando
# Pandas.

import pandas as pd
from google.colab import files

uploaded = files.upload() # Diálogo para que el usuario suba un archivo desde su computadora

df_csv = pd.read_csv('ventas - Hoja 1.csv', sep=';', encoding='latin-1') # Especifica el separador
                    # como ; y usa codificación latin-1 para manejar correctamente caracteres especiales
df = df_csv.dropna(how='all') # Elimina filas donde las columnas tienen valores nulos/NaN

print("Primeras 5 filas del CSV:")
print(df_csv.head()) # Imprime las primeras 5 filas del documento
# Out:
#      <input type="file" id="files-d43e25be-dd4a-414c-ae9f-8940985b18a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d43e25be-dd4a-414c-ae9f-8940985b18a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#2. Repetir el ejercicio anterior con una planilla de Google Sheets.

import pandas as pd

SHEET_ID = "1UE0N6fjG7yeMAN4C8Z3d7o4h8P8CAfEO9AnAa8gGgSw" # Identificador único de la hoja de Google Sheets
sheet_url = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=csv" #URL que permite exportar la hoja como CSV

df_csv = pd.read_csv(sheet_url) # Lee el archivo CSV directamente desde la URL de Google Sheets
df = df_csv.dropna(how='all')

print("Primeras 5 filas:")
print(df.head())
# Out:
# Primeras 5 filas:
#         Fecha     Vendedor Sede Entrega    Producto     Importe
# 0  06/11/2020  Vendedor 10       Sede D  Producto Z   $75880.72
# 1  01/10/2021  Vendedor 10       Sede D  Producto Y  $279412.05
# 2  09/05/2021   Vendedor 4       Sede A  Producto W         NaN
# 3  07/10/2021   Vendedor 3       Sede D  Producto U   $33830.98
# 4  02/08/2021   Vendedor 3       Sede C  Producto U  $205706.84

# %%
# 3. Investigá el método para cargar planillas de Excel en Google Colab,
# utilizando Pandas, y repetí el ejercicio del punto 1.

import pandas as pd
from google.colab import files

uploaded = files.upload()

df_csv = pd.read_csv('Ejemplo1.csv', sep=';', encoding='latin-1')
df = df_csv.dropna(how='all')

print("Primeras 5 filas del CSV:")
print(df.head())
# Out:
#      <input type="file" id="files-f943b8d5-d30f-4a0e-940e-54771b56b8d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f943b8d5-d30f-4a0e-940e-54771b56b8d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
